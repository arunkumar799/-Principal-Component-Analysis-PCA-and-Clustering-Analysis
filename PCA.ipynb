# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploratory Data Analysis (EDA) process.

# %%
df = pd.read_csv(r"C:\Users\reddy\Downloads\data assingnment files\Assingnment files\Completed\PCA\wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.shape
# Out:
# (178, 14)

# %% [markdown]
# ### Saperation of features and target

# %%
features = df.drop(columns='Type')
target = df[['Type']]

# %% [markdown]
# ### Visuvalization of the data for understanding.

# %%
plt.figure(figsize=(30,15))
features.hist()
# Out:
# array([[<Axes: title={'center': 'Alcohol'}>,
#         <Axes: title={'center': 'Malic'}>,
#         <Axes: title={'center': 'Ash'}>,
#         <Axes: title={'center': 'Alcalinity'}>],
#        [<Axes: title={'center': 'Magnesium'}>,
#         <Axes: title={'center': 'Phenols'}>,
#         <Axes: title={'center': 'Flavanoids'}>,
#         <Axes: title={'center': 'Nonflavanoids'}>],
#        [<Axes: title={'center': 'Proanthocyanins'}>,
#         <Axes: title={'center': 'Color'}>,
#         <Axes: title={'center': 'Hue'}>,
#         <Axes: title={'center': 'Dilution'}>],
#        [<Axes: title={'center': 'Proline'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
box_graph = sns.boxplot(features)
box_graph
# Out:
# <Axes: >

# %% [markdown]
# ### Co-relation to understand the relation between the data

# %%
corr =features.corr()
corr
# Out:
#                   Alcohol     Malic       Ash  Alcalinity  Magnesium  \
# Alcohol          1.000000  0.094397  0.211545   -0.310235   0.270798
# Malic            0.094397  1.000000  0.164045    0.288500  -0.054575
# Ash              0.211545  0.164045  1.000000    0.443367   0.286587
# Alcalinity      -0.310235  0.288500  0.443367    1.000000  -0.083333
# Magnesium        0.270798 -0.054575  0.286587   -0.083333   1.000000
# Phenols          0.289101 -0.335167  0.128980   -0.321113   0.214401
# Flavanoids       0.236815 -0.411007  0.115077   -0.351370   0.195784
# Nonflavanoids   -0.155929  0.292977  0.186230    0.361922  -0.256294
# Proanthocyanins  0.136698 -0.220746  0.009652   -0.197327   0.236441
# Color            0.546364  0.248985  0.258887    0.018732   0.199950
# Hue             -0.071747 -0.561296 -0.074667   -0.273955   0.055398
# Dilution         0.072343 -0.368710  0.003911   -0.276769   0.066004
# Proline          0.643720 -0.192011  0.223626   -0.440597   0.393351
#
# ...

# %%
#Heatmap for understading the relation between data.
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# ### To applying the standardscaler for better performance

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(features))
scaled_data
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.518613 -0.562250  0.232053 -1.169593  1.913905  0.808997  1.034819
# 1    0.246290 -0.499413 -0.827996 -2.490847  0.018145  0.568648  0.733629
# 2    0.196879  0.021231  1.109334 -0.268738  0.088358  0.808997  1.215533
# 3    1.691550 -0.346811  0.487926 -0.809251  0.930918  2.491446  1.466525
# 4    0.295700  0.227694  1.840403  0.451946  1.281985  0.808997  0.663351
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  0.876275  2.974543  0.305159  0.301803 -0.332922 -0.985614 -1.424900
# 174  0.493343  1.412609  0.414820  1.052516  0.158572 -0.793334 -1.284344
# 175  0.332758  1.744744 -0.389355  0.151661  1.422412 -1.129824 -1.344582
# 176  0.209232  0.227694  0.012732  0.151661  1.422412 -1.033684 -1.354622
# 177  1.395086  1.583165  1.365208  1.502943 -0.262708 -0.392751 -1.274305
#
#            7         8         9         10        11        12
# ...

# %% [markdown]
# ### Rename after appling of the standard scaler.

# %%
old_name = range(0,13)
new_name = features.columns
features1 = scaled_data.rename(columns=dict(zip(old_name,new_name)))
features1
# Out:
#       Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0    1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997
# 1    0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648
# 2    0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997
# 3    1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446
# 4    0.295700  0.227694  1.840403    0.451946   1.281985  0.808997
# ..        ...       ...       ...         ...        ...       ...
# 173  0.876275  2.974543  0.305159    0.301803  -0.332922 -0.985614
# 174  0.493343  1.412609  0.414820    1.052516   0.158572 -0.793334
# 175  0.332758  1.744744 -0.389355    0.151661   1.422412 -1.129824
# 176  0.209232  0.227694  0.012732    0.151661   1.422412 -1.033684
# 177  1.395086  1.583165  1.365208    1.502943  -0.262708 -0.392751
#
#      Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  Dilution  \
# 0      1.034819      -0.659563         1.224884  0.251717  0.362177  1.847920
# ...

# %% [markdown]
# # Dimensionality Reduction with PCA

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
pca= PCA(n_components=8)

# %%
dg = pca.fit(features1)
dg
# Out:
# PCA(n_components=8)

# %%
new_features= pca.transform(features1)
new_features=pd.DataFrame(new_features)

# %%
old_name1 = range(0,13)
new_name1 = features.columns
New_features = new_features.rename(columns=dict(zip(old_name1,new_name1)))
New_features
# Out:
#       Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0    3.316751  1.443463 -0.165739   -0.215631   0.693043  0.223880
# 1    2.209465 -0.333393 -2.026457   -0.291358  -0.257655  0.927120
# 2    2.516740  1.031151  0.982819    0.724902  -0.251033 -0.549276
# 3    3.757066  2.756372 -0.176192    0.567983  -0.311842 -0.114431
# 4    1.008908  0.869831  2.026688   -0.409766   0.298458  0.406520
# ..        ...       ...       ...         ...        ...       ...
# 173 -3.370524  2.216289 -0.342570    1.058527  -0.574164  1.108788
# 174 -2.601956  1.757229  0.207581    0.349496   0.255063  0.026465
# 175 -2.677839  2.760899 -0.940942    0.312035   1.271355 -0.273068
# 176 -2.387017  2.297347 -0.550696   -0.688285   0.813955 -1.178783
# 177 -3.208758  2.768920  1.013914    0.596903  -0.895193 -0.296092
#
#      Flavanoids  Nonflavanoids
# 0      0.596427      -0.065139
# 1      0.053776      -1.024416
# 2      0.424205       0.344216
# 3     -0.383337      -0.643593
# ...

# %% [markdown]
# # Clustering with Original Data:Applying the K_means for data

# %%
from sklearn.cluster import KMeans

# %%
Km = KMeans(n_clusters=8)

# %%
clusters = Km.fit(features)
clusters
# Out:
# KMeans()

# %%
clusters1 = clusters.labels_
labels = Km.fit_predict(features1)

# %% [markdown]
# ### Visualize the clustered result

# %%
sns.scatterplot(data=features1, x='Alcohol', y='Magnesium', hue=clusters1)
plt.show()

# %% [markdown]
# # Clustering with PCA Data

# %% [markdown]
# ### To apply the new data to the K-means.

# %%
cluster2 = Km.fit(new_features)
cluster2
# Out:
# KMeans()

# %%
clusters4 = cluster2 .labels_
labels1 = Km.fit_predict(features1)

# %%
sns.scatterplot(data=New_features, x='Alcohol', y='Magnesium', hue=labels1)
plt.show()

# %% [markdown]
# ## While comparing before and after PCA straightly changes in the data.

# %% [markdown]
# # Evaluate clustering performance

# %%
from sklearn.metrics import silhouette_score
silhouette = silhouette_score(New_features, labels1)

# %% [markdown]
# # Comparison and Analysis

# %%
# Apply PCA
pca = PCA(n_components=2)  # Reduce to 2 components for visualization
pca_data = pca.fit_transform(new_features)

# Fit KMeans on original data
kmeans_orig = KMeans(n_clusters=3).fit(new_features)
labels_orig = kmeans_orig.labels_

# Fit KMeans on PCA-transformed data
kmeans_pca = KMeans(n_clusters=3).fit(pca_data)
labels_pca = kmeans_pca.labels_

# Silhouette scores
silhouette_orig = silhouette_score(new_features, labels_orig)
silhouette_pca = silhouette_score(pca_data, labels_pca)
print(f"Silhouette Score on Original Data: {silhouette_orig}")
print(f"Silhouette Score on PCA Data: {silhouette_pca}")

# Plotting clusters for comparison
plt.figure(figsize=(12, 6))

# Original Data clusters
plt.subplot(1, 2, 1)
plt.scatter(features1['Alcohol'], features1['Magnesium'], c=labels_orig, cmap='viridis')
plt.title('Clustering on Original Data')
# Out:
# Silhouette Score on Original Data: 0.31496969547055614
# Silhouette Score on PCA Data: 0.5610505693103245
# Text(0.5, 1.0, 'Clustering on Original Data')

# %% [markdown]
# ### After applying the PCA the resultant features showned in the graph

# %%
plt.subplot(1, 2, 1)
plt.scatter(New_features['Alcohol'], New_features['Magnesium'], c=labels_orig, cmap='viridis')
plt.title("PCA-transformed data clustering results")
# Out:
# Text(0.5, 1.0, 'PCA-transformed data clustering results')

# %% [markdown]
# # Conclusion and Insights

# %%
from sklearn.metrics import davies_bouldin_score

# %%
# Summarize the results
print("Summary of clustering results:")
print("Original dataset:")
print("  Number of clusters:", Km.n_clusters)
print("  Silhouette score:", silhouette_score(features1, Km.labels_))
print("  Davies-Bouldin index:", davies_bouldin_score(features1, Km.labels_))

print("\nPCA-transformed data:")
print("  Number of clusters:", Km.n_clusters)
print("  Silhouette score:", silhouette_score(New_features, Km.labels_))
print("  Davies-Bouldin index:", davies_bouldin_score(New_features, Km.labels_))
# Out:
# Summary of clustering results:
# Original dataset:
#   Number of clusters: 8
#   Silhouette score: 0.1561075121149036
#   Davies-Bouldin index: 1.683662298933137
#
# PCA-transformed data:
#   Number of clusters: 8
#   Silhouette score: 0.18171396759879943
#   Davies-Bouldin index: 1.5261454730148567
